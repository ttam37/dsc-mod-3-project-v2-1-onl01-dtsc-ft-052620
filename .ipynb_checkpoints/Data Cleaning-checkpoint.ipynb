# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import Data

# %%
# will only be using these 2 datasets which include the overview of each game and the team's information
# does not include player's information for each game
data_games = pd.read_csv('nba_games_data/games.csv')
data_teams = pd.read_csv('nba_games_data/teams.csv')
data_games_details = pd.read_csv('nba_games_data/games_details.csv')

# %%
data_games_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  21900895  1610612749               MIL  Milwaukee     202083
# 1  21900895  1610612749               MIL  Milwaukee     203507
# 2  21900895  1610612749               MIL  Milwaukee     201572
# 3  21900895  1610612749               MIL  Milwaukee    1628978
# 4  21900895  1610612749               MIL  Milwaukee     202339
#
#              PLAYER_NAME START_POSITION COMMENT    MIN   FGM  ...  OREB  DREB  \
# 0        Wesley Matthews              F     NaN  27:08   3.0  ...   4.0   4.0
# 1  Giannis Antetokounmpo              F     NaN  34:55  17.0  ...   2.0  18.0
# 2            Brook Lopez              C     NaN  26:25   4.0  ...   2.0   5.0
# 3       Donte DiVincenzo              G     NaN  27:35   1.0  ...   1.0   6.0
# 4           Eric Bledsoe              G     NaN  22:17   2.0  ...   1.0   0.0
#
#     REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0   8.0  2.0  2.0  0.0  0.0  0.0   8.0        11.0
# ...

# %%
data_games.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2019    1610612766      85.0        0.354        0.900  ...      22.0
# 1    2019    1610612750      91.0        0.364        0.400  ...      19.0
# 2    2019    1610612746     136.0        0.592        0.805  ...      25.0
# 3    2019    1610612743     133.0        0.566        0.700  ...      38.0
# 4    2019    1610612758     106.0        0.407        0.885  ...      18.0
#
# ...

# %%
data_games.shape
# Out:
# (23195, 21)

# %%
data_games_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0  21900895  1610612749               MIL  Milwaukee     202083
# 1  21900895  1610612749               MIL  Milwaukee     203507
# 2  21900895  1610612749               MIL  Milwaukee     201572
# 3  21900895  1610612749               MIL  Milwaukee    1628978
# 4  21900895  1610612749               MIL  Milwaukee     202339
#
#              PLAYER_NAME START_POSITION COMMENT    MIN   FGM  ...  OREB  DREB  \
# 0        Wesley Matthews              F     NaN  27:08   3.0  ...   4.0   4.0
# 1  Giannis Antetokounmpo              F     NaN  34:55  17.0  ...   2.0  18.0
# 2            Brook Lopez              C     NaN  26:25   4.0  ...   2.0   5.0
# 3       Donte DiVincenzo              G     NaN  27:35   1.0  ...   1.0   6.0
# 4           Eric Bledsoe              G     NaN  22:17   2.0  ...   1.0   0.0
#
#     REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0   8.0  2.0  2.0  0.0  0.0  0.0   8.0        11.0
# ...

# %% [markdown]
# # Add Additional Stats

# %%
# create pivot table to aggregate the stats
additional_stats = pd.pivot_table(data_games_details, values=['STL','BLK','TO','PF'],
                       index=['GAME_ID','TEAM_ID'],aggfunc=np.sum).reset_index()
additional_stats.head()
# Out:
#     GAME_ID     TEAM_ID  BLK    PF   STL    TO
# 0  10300001  1610612742  4.0  34.0   9.0  18.0
# 1  10300001  1610612762  4.0  26.0   8.0  18.0
# 2  10300002  1610612749  4.0  26.0   9.0  24.0
# 3  10300002  1610612763  7.0  35.0  18.0  25.0
# 4  10300003  1610612739  7.0  33.0  10.0  25.0

# %%
# merge dataframe with the additional stats (home)
df = data_games.merge(additional_stats[['GAME_ID','TEAM_ID','BLK','PF','STL','TO']], 
              left_on= ['GAME_ID','HOME_TEAM_ID'], 
              right_on = ['GAME_ID','TEAM_ID'])
df = df.rename(columns={'BLK': 'BLK_home','PF': 'PF_home','STL': 'STL_home','TO': 'TO_home'})
df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  FT_PCT_away  \
# 0    2019    1610612766      85.0        0.354        0.900  ...        0.762
# 1    2019    1610612750      91.0        0.364        0.400  ...        0.632
# 2    2019    1610612746     136.0        0.592        0.805  ...        0.650
# 3    2019    1610612743     133.0        0.566        0.700  ...        0.897
# 4    2019    1610612758     106.0        0.407        0.885  ...        0.667
#
# ...

# %%
# merge dataframe with the additional stats (away)
df = df.merge(additional_stats[['GAME_ID','TEAM_ID','BLK','PF','STL','TO']], 
              left_on= ['GAME_ID','VISITOR_TEAM_ID'], 
              right_on = ['GAME_ID','TEAM_ID'])
df = df.rename(columns={'BLK': 'BLK_away','PF': 'PF_away','STL': 'STL_away','TO': 'TO_away'})
df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...   TEAM_ID_x  \
# 0    2019    1610612766      85.0        0.354        0.900  ...  1610612766
# 1    2019    1610612750      91.0        0.364        0.400  ...  1610612750
# 2    2019    1610612746     136.0        0.592        0.805  ...  1610612746
# 3    2019    1610612743     133.0        0.566        0.700  ...  1610612743
# 4    2019    1610612758     106.0        0.407        0.885  ...  1610612758
#
# ...

# %%
# remove overlapped columns
added_stats_df = df.drop(['TEAM_ID_x','TEAM_ID_y','TEAM_ID_x','TEAM_ID_y','TEAM_ID_home','TEAM_ID_away'],axis=1)
added_stats_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  ...  REB_away  \
# 0    2019      85.0        0.354        0.900         0.229  ...      61.0
# 1    2019      91.0        0.364        0.400         0.310  ...      56.0
# 2    2019     136.0        0.592        0.805         0.542  ...      37.0
# 3    2019     133.0        0.566        0.700         0.500  ...      36.0
# 4    2019     106.0        0.407        0.885         0.257  ...      42.0
#
# ...

# %% [markdown]
# # Replace Team ID with Team Name

# %%
# pd.pivot_table(a, values='TO',index=['GAME_ID','TEAM_ID'],aggfunc=np.sum).reset_index()

# %%
added_stats_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2020-03-01  21900895            Final    1610612766       1610612749
# 1    2020-03-01  21900896            Final    1610612750       1610612742
# 2    2020-03-01  21900897            Final    1610612746       1610612755
# 3    2020-03-01  21900898            Final    1610612743       1610612761
# 4    2020-03-01  21900899            Final    1610612758       1610612765
#
#    SEASON  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  ...  REB_away  \
# 0    2019      85.0        0.354        0.900         0.229  ...      61.0
# 1    2019      91.0        0.364        0.400         0.310  ...      56.0
# 2    2019     136.0        0.592        0.805         0.542  ...      37.0
# 3    2019     133.0        0.566        0.700         0.500  ...      36.0
# 4    2019     106.0        0.407        0.885         0.257  ...      42.0
#
# ...

# %%
# replace home team_id with the team name for easier readability
final_data = added_stats_df.merge(data_teams[['TEAM_ID','NICKNAME']], left_on='HOME_TEAM_ID', right_on='TEAM_ID')
final_data = final_data.drop(['HOME_TEAM_ID'],axis=1)
final_data = final_data.rename(columns={"NICKNAME": "HOME_TEAM"})
final_data.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  VISITOR_TEAM_ID  SEASON  PTS_home  \
# 0    2020-03-01  21900895            Final       1610612749    2019      85.0
# 1    2020-02-26  21900864            Final       1610612752    2019     107.0
# 2    2020-02-22  21900836            Final       1610612751    2019      86.0
# 3    2020-02-08  21900778            Final       1610612742    2019     100.0
# 4    2020-02-03  21900741            Final       1610612753    2019     100.0
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  ...  BLK_home  PF_home  \
# 0        0.354        0.900         0.229      22.0  ...       8.0     18.0
# 1        0.470        0.760         0.333      25.0  ...       4.0     19.0
# 2        0.352        0.571         0.343      22.0  ...       2.0     16.0
# 3        0.437        0.722         0.306      15.0  ...       4.0     13.0
# 4        0.461        0.643         0.290      24.0  ...       2.0     16.0
#
# ...

# %%
# replace away team_id with the team name for easier readability
final_data = final_data.merge(data_teams[['TEAM_ID','NICKNAME']], left_on='VISITOR_TEAM_ID', right_on='TEAM_ID')
final_data = final_data.drop(['VISITOR_TEAM_ID','TEAM_ID_x','TEAM_ID_y'],axis=1)
final_data = final_data.rename(columns={"NICKNAME": "VISITOR_TEAM"})
final_data.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  SEASON  PTS_home  FG_PCT_home  \
# 0    2020-03-01  21900895            Final    2019      85.0        0.354
# 1    2020-01-24  21900669            Final    2019     103.0        0.372
# 2    2013-12-23  21300407            Final    2013     111.0        0.434
# 3    2013-11-29  21300228            Final    2013      92.0        0.443
# 4    2013-04-13  21201190            Final    2012      95.0        0.463
#
#    FT_PCT_home  FG3_PCT_home  AST_home  REB_home  ...  BLK_home  PF_home  \
# 0        0.900         0.229      22.0      47.0  ...       8.0     18.0
# 1        0.833         0.359      24.0      39.0  ...       3.0     22.0
# 2        0.750         0.588      30.0      43.0  ...       7.0     17.0
# 3        0.613         0.200      20.0      54.0  ...       4.0     17.0
# 4        0.708         0.444      23.0      52.0  ...       5.0     18.0
#
#    STL_home  TO_home  BLK_away  PF_away  STL_away  TO_away  HOME_TEAM  \
# ...

# %%
final_data.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  SEASON  PTS_home  FG_PCT_home  \
# 0    2020-03-01  21900895            Final    2019      85.0        0.354
# 1    2020-01-24  21900669            Final    2019     103.0        0.372
# 2    2013-12-23  21300407            Final    2013     111.0        0.434
# 3    2013-11-29  21300228            Final    2013      92.0        0.443
# 4    2013-04-13  21201190            Final    2012      95.0        0.463
#
#    FT_PCT_home  FG3_PCT_home  AST_home  REB_home  ...  BLK_home  PF_home  \
# 0        0.900         0.229      22.0      47.0  ...       8.0     18.0
# 1        0.833         0.359      24.0      39.0  ...       3.0     22.0
# 2        0.750         0.588      30.0      43.0  ...       7.0     17.0
# 3        0.613         0.200      20.0      54.0  ...       4.0     17.0
# 4        0.708         0.444      23.0      52.0  ...       5.0     18.0
#
#    STL_home  TO_home  BLK_away  PF_away  STL_away  TO_away  HOME_TEAM  \
# ...

# %% [markdown]
# # 2. Inspect Data

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23096 entries, 0 to 23095
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     23096 non-null  object
#  1   GAME_ID           23096 non-null  int64
#  2   GAME_STATUS_TEXT  23096 non-null  object
#  3   SEASON            23096 non-null  int64
#  4   PTS_home          23096 non-null  float64
#  5   FG_PCT_home       23096 non-null  float64
#  6   FT_PCT_home       23096 non-null  float64
#  7   FG3_PCT_home      23096 non-null  float64
#  8   AST_home          23096 non-null  float64
#  9   REB_home          23096 non-null  float64
#  10  PTS_away          23096 non-null  float64
#  11  FG_PCT_away       23096 non-null  float64
#  12  FT_PCT_away       23096 non-null  float64
#  13  FG3_PCT_away      23096 non-null  float64
#  14  AST_away          23096 non-null  float64
#  15  REB_away          23096 non-null  float64
# ...

# %%
final_data.hist(figsize=(20,20));

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# ## Remove Duplicates
#
# The only column that needs to be checked is GAME_ID to check if there are any duplicate entries.

# %%
# print the number of duplicate entries
duplicates = final_data['GAME_ID'].duplicated().sum()
print(f'There are {duplicates} duplicate entries in GAME_ID.')
# Out:
# There are 0 duplicate entries in GAME_ID.

# %% [markdown]
# ## Remove Features

# %%
final_data.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'SEASON', 'PTS_home',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
#        'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
#        'REB_away', 'HOME_TEAM_WINS', 'BLK_home', 'PF_home', 'STL_home',
#        'TO_home', 'BLK_away', 'PF_away', 'STL_away', 'TO_away', 'HOME_TEAM',
#        'VISITOR_TEAM'],
#       dtype='object')

# %%
# removing unimportant features
final_data = final_data.drop(['GAME_ID','GAME_STATUS_TEXT','GAME_DATE_EST'],axis=1)
final_data.head()
# Out:
#    SEASON  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0    2019      85.0        0.354        0.900         0.229      22.0
# 1    2019     103.0        0.372        0.833         0.359      24.0
# 2    2013     111.0        0.434        0.750         0.588      30.0
# 3    2013      92.0        0.443        0.613         0.200      20.0
# 4    2012      95.0        0.463        0.708         0.444      23.0
#
#    REB_home  PTS_away  FG_PCT_away  FT_PCT_away  ...  BLK_home  PF_home  \
# 0      47.0      93.0        0.402        0.762  ...       8.0     18.0
# 1      39.0     116.0        0.506        0.750  ...       3.0     22.0
# 2      43.0     110.0        0.433        0.941  ...       7.0     17.0
# 3      54.0      76.0        0.333        0.750  ...       4.0     17.0
# 4      52.0      85.0        0.391        0.667  ...       5.0     18.0
#
#    STL_home  TO_home  BLK_away  PF_away  STL_away  TO_away  HOME_TEAM  \
# ...

# %%
# # removing point features
# final_data = final_data.drop(['PTS_home','PTS_away'],axis=1)
# final_data.head()

# %% [markdown]
# ## Missing Null Values

# %%
def find_null_cols(df):
    df_clone = df.copy()
    print('\'NaN\' found in columns as follows:')
    for col in df_clone.columns:
        if (df_clone[col].isnull().any()) | (df_clone[col].isna().any()):
            print(f'\t{col:30} contains {df_clone[col].isna().sum():10} null values ({df_clone[col].isna().sum()*100/df_clone.shape[0]:5.2f}%) !')
    return None

print(final_data.shape)
find_null_cols(final_data)
# Out:
# (23096, 24)
# 'NaN' found in columns as follows:

# %%
# the entire dataset has 99 rows with missing values which we will remove
final_data = final_data.dropna()

# check dataframe shape
print(final_data.shape)

# checking the null values were removed
find_null_cols(final_data)
# Out:
# (23096, 24)
# 'NaN' found in columns as follows:

# %%
final_data.isnull().sum()
# Out:
# SEASON            0
# PTS_home          0
# FG_PCT_home       0
# FT_PCT_home       0
# FG3_PCT_home      0
# AST_home          0
# REB_home          0
# PTS_away          0
# FG_PCT_away       0
# FT_PCT_away       0
# FG3_PCT_away      0
# AST_away          0
# REB_away          0
# HOME_TEAM_WINS    0
# BLK_home          0
# PF_home           0
# STL_home          0
# TO_home           0
# BLK_away          0
# PF_away           0
# STL_away          0
# TO_away           0
# HOME_TEAM         0
# VISITOR_TEAM      0
# dtype: int64

# %% [markdown]
# # Export Files

# %%
final_data.to_csv('csv_files/processed_data.csv')

# %% [markdown]
# ## Checking for Outliers

# %% [markdown]
# # 4. Binning Categorical Data

# %%
# df.info()

# %%
# pd.set_option('display.max_columns', None)
# df.head()

# %%
# categorical = ['SEASON','HOME_TEAM_WINS','CITY','HOME_TEAM','ARENA','VISITOR_TEAM','GAME_MONTH_PLAYED','GAME_YEAR_PLAYED']

# continuous = ['PTS_home','FG_PCT_home','FT_PCT_home','FG3_PCT_home','AST_home','REB_home','PTS_away',
#               'FG_PCT_away','FT_PCT_away','FG3_PCT_away','AST_away','REB_away']

# %%
# categorical_data = df[['HOME_TEAM_WINS','ARENA','SEASON']]
# continuous_data = df[['PTS_home','FG_PCT_home','FT_PCT_home','FG3_PCT_home','AST_home','REB_home','PTS_away',
#                       'FG_PCT_away','FT_PCT_away','FG3_PCT_away','AST_away','REB_away']]

# %%
# def convert_category(df):
#     for column in df.columns:
#         if column == 'HOME_TEAM_WINS':
#             continue
#         df[column] = df[column].astype('category')
#     return None

# convert_category(categorical_data)

# %%
# dummies_data = pd.get_dummies(categorical_data)
# dummies_data

# %%
# # concat the log/normalized continuous data with the dummy data
# final_data = pd.concat([continuous_data,dummies_data],axis=1).dropna()
# final_data.head()

# %%
# a = df[['HOME_TEAM','FG_PCT_home']]
# b = df[['VISITOR_TEAM','FG_PCT_away']]

# %%
# all_dfs = [a,b]

# # Give all df's common column names
# for df in all_dfs:
#     df.columns = ['TEAM', 'FG_PCT']

# c = pd.concat(all_dfs).reset_index(drop=True)

# %%
# table = pd.pivot_table(c, values='FG_PCT', index=['TEAM'], aggfunc=np.mean).reset_index()
# table

# %% [markdown]
# # 5. Multicollinearity

# %%
# plt.figure(figsize = (15, 8))
# sns.heatmap(abs(final_data.corr())> 0.70, cmap = 'coolwarm');

# %%
# # This outputs the top highest correlated pairs
# df_pairs = final_data.corr().abs().stack().reset_index().sort_values(0, ascending = False)
# df_pairs['pairs'] = list(zip(df_pairs.level_0, df_pairs.level_1))
# df_pairs.set_index(['pairs'], inplace = True)
# df_pairs.drop(columns = ['level_1', 'level_0'], inplace = True)
# df_pairs.columns = ['correlation']
# df_pairs.drop_duplicates(inplace = True)

# %%
# # Output the top correlated pairs
# df_pairs[(df_pairs.correlation >.70) & (df_pairs.correlation <1)].reset_index()
